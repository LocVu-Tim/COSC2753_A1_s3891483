# %% [markdown]
# # Exploratory Data Analysis
# ***

# %%
# Imports and environment 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Overview
#
# ###### Load dataset:

# %%
df_train = pd.read_csv("../data/data_train.csv") # Train data
df_test = pd.read_csv("../data/data_test.csv") # Test data

# %% [markdown]
# ### 1.1. Train Data

# %%
print(f"{('SHAPE')}\n{df_train.shape}")
print(f"\n{('NULL VALUES COUNT')}\n{df_train.isna().sum()}")
print(f"\n{('COLUMNS OVERVIEW')}")
print(df_train.info())
# Out:
# SHAPE
# (202944, 25)
#
# NULL VALUES COUNT
# Id                      0
# HighBP                  0
# HighChol                0
# CholCheck               0
# BMI                     0
# Smoker                  0
# Stroke                  0
# HeartDiseaseorAttack    0
# PhysActivity            0
# Fruits                  0
# Veggies                 0
# HvyAlcoholConsump       0
# AnyHealthcare           0
# NoDocbcCost             0
# GenHlth                 0
# MentHlth                0
# PhysHlth                0
# DiffWalk                0
# Sex                     0
# Age                     0
# Education               0
# Income                  0
# ExtraMedTest            0
# ExtraAlcoholTest        0
# Status                  0
# dtype: int64
#
# COLUMNS OVERVIEW
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202944 entries, 0 to 202943
# Data columns (total 25 columns):
#  #   Column                Non-Null Count   Dtype
# ...

# %%
df_train.describe()
# Out:
#                   Id         HighBP       HighChol      CholCheck  \
# count  202944.000000  202944.000000  202944.000000  202944.000000
# mean   101471.500000       0.428700       0.424344       0.962655
# std     58585.030853       0.494891       0.494244       0.189607
# min         0.000000       0.000000       0.000000       0.000000
# 25%     50735.750000       0.000000       0.000000       1.000000
# 50%    101471.500000       0.000000       0.000000       1.000000
# 75%    152207.250000       1.000000       1.000000       1.000000
# max    202943.000000       1.000000       1.000000       1.000000
#
#                  BMI         Smoker         Stroke  HeartDiseaseorAttack  \
# count  202944.000000  202944.000000  202944.000000         202944.000000
# mean       28.379824       0.442634       0.040844              0.094391
# std         6.612738       0.496700       0.197929              0.292372
# min        12.000000       0.000000       0.000000              0.000000
# ...

# %%
df_train.head()
# Out:
#    Id  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  HeartDiseaseorAttack  \
# 0   0       0         0          1   24       1       0                     0
# 1   1       0         0          1   28       0       0                     0
# 2   2       0         0          1   36       1       0                     0
# 3   3       0         1          1   35       0       0                     0
# 4   4       0         1          1   27       0       0                     0
#
#    PhysActivity  Fruits  ...  MentHlth  PhysHlth  DiffWalk  Sex  Age  \
# 0             1       0  ...         0         0         0    0    8
# 1             1       1  ...         1         0         0    0    2
# 2             1       1  ...        30        30         1    0    3
# 3             1       1  ...         0         0         0    0    8
# 4             1       0  ...         0         0         0    0    9
#
#    Education  Income  ExtraMedTest  ExtraAlcoholTest  Status
# ...

# %% [markdown]
# ### 1.2. Test Data

# %%
print(f"{('SHAPE')}\n{df_test.shape}")
print(f"\n{('NULL VALUES COUNT')}\n{df_test.isna().sum()}")
print(f"\n{('COLUMNS OVERVIEW')}")
print(df_test.info())
# Out:
# SHAPE
# (50736, 25)
#
# NULL VALUES COUNT
# Id                          0
# HighBP                      0
# HighChol                    0
# CholCheck                   0
# BMI                         0
# Smoker                      0
# Stroke                      0
# HeartDiseaseorAttack        0
# PhysActivity                0
# Fruits                      0
# Veggies                     0
# HvyAlcoholConsump           0
# AnyHealthcare               0
# NoDocbcCost                 0
# GenHlth                     0
# MentHlth                    0
# PhysHlth                    0
# DiffWalk                    0
# Sex                         0
# Age                         0
# Education                   0
# Income                      0
# ExtraMedTest                0
# ExtraAlcoholTest            0
# Status                  50736
# dtype: int64
#
# COLUMNS OVERVIEW
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50736 entries, 0 to 50735
# Data columns (total 25 columns):
# ...

# %%
df_test.describe()
# Out:
#                   Id        HighBP      HighChol     CholCheck           BMI  \
# count   50736.000000  50736.000000  50736.000000  50736.000000  50736.000000
# mean   228311.500000      0.430207      0.423230      0.962729     28.392522
# std     14646.365966      0.495110      0.494076      0.189428      6.592550
# min    202944.000000      0.000000      0.000000      0.000000     12.000000
# 25%    215627.750000      0.000000      0.000000      1.000000     24.000000
# 50%    228311.500000      0.000000      0.000000      1.000000     27.000000
# 75%    240995.250000      1.000000      1.000000      1.000000     31.000000
# max    253679.000000      1.000000      1.000000      1.000000     95.000000
#
#              Smoker        Stroke  HeartDiseaseorAttack  PhysActivity  \
# count  50736.000000  50736.000000          50736.000000  50736.000000
# mean       0.445305      0.039479              0.093366      0.757509
# ...

# %%
df_test.head()
# Out:
#        Id  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0  202944       1         1          1   30       1       0
# 1  202945       0         0          1   27       1       0
# 2  202946       0         0          1   21       0       0
# 3  202947       0         0          1   24       1       0
# 4  202948       1         0          1   34       0       0
#
#    HeartDiseaseorAttack  PhysActivity  Fruits  ...  MentHlth  PhysHlth  \
# 0                     1             1       1  ...         3         0
# 1                     0             0       0  ...         0        30
# 2                     0             1       1  ...         0         5
# 3                     0             1       1  ...         0        30
# 4                     0             1       1  ...         0         1
#
#    DiffWalk  Sex  Age  Education  Income  ExtraMedTest  ExtraAlcoholTest  \
# 0         0    1   11          4       7             0              -145
# ...

# %% [markdown]
# | Features |  Data Type | Description | Range | Source
# | :-- | :--: | :-- | :-- | :--:|
# | HighBP | int64 | High blood preasure | -asdsad -asdasd -asdasd | asd
# | HighChol | int64| High cholesterol | -asdsad -asdasd -asdasd | asd
# | CholCheck | int64| Cholestero check in 5 years | -asdsad -asdasd -asdasd | asd
# | BMI | int64| Body Mass Index | -asdsad -asdasd -asdasd | asd
# | Smoker | int64| Have patients smoked at least 100 cigarettes in their entire life? (Note: 5 packs = 100 cigarettes) | -asdsad -asdasd -asdasd | asd
# | Stroke | int64| Have patients ever they had a stroke? | -asdsad -asdasd -asdasd | asd
# | HeartDiseaseorAttack | int64| coronary heart disease (CHD) or myocardial infarction (MI) | - Normal: 3.9 < `PRG` < 5.6<br/>- At risk of diabetes: 5.6 < `PRG` < 6.9<br/>- Diabetes 7.0 < `PRG` | asd
# | PhysActivity | int64| Physical activity in past 30 days - not including jobs | -asdsad -asdasd -asdasd | asd
# | Fruits | int64| Consume Fruit 1 or more times per day | -asdsad -asdasd -asdasd | asd
# | Veggies | int64| Consume Vegetables 1 or more times per day | -asdsad -asdasd -asdasd | asd
# | HvyAlcoholConsump | int64| Heavy drinkers (adult men having more than 14 drinks per week and adult women having more than 7 drinks per week)| -asdsad -asdasd -asdasd | asd
# | AnyHealthcare | int64| Have any kind of health care coverage, including health insurance, prepaid plans such as HMO, etc. | -asdsad -asdasd -asdasd | asd
# | NoDocbcCost | int64| Was there a time in the past 12 months when patient needed to see a doctor but could not because of cost? | -asdsad -asdasd -asdasd | asd
# | GenHlth | int64| How patient said their health in general is | -asdsad -asdasd -asdasd | asd
# | MentHlth | int64| Patients' Metal Health (stress, depression, and problems with emotions, for how many days during the past 30 days was their mental health not good? | -asdsad -asdasd -asdasd | asd
# | PhysHlth | int64| Patients' Physical Health (physical illness and injury, for how many days during the past 30 days was their physical health not good?| -asdsad -asdasd -asdasd | asd
# | DiffWalk | int64| Do patient have serious difficulty walking or climbing stairs? | -asdsad -asdasd -asdasd | asd
# | Sex | int64| Patient's sex | -asdsad -asdasd -asdasd | asd
# | Age | int64| Patient's age | -asdsad -asdasd -asdasd | asd
# | Education | int64| Patient's Education level ($levels$) | -asdsad -asdasd -asdasd | asd
# | Income | int64| Patient's income level ($levels$) | -asdsad -asdasd -asdasd | asd
# | ExtraMedTest | int64| The result of an extra medical test ($range$) | -asdsad -asdasd -asdasd | asd
# | ExtraAlcoholTest | int64| The result of an extra alcohol test ($range$) | -asdsad -asdasd -asdasd | asd
